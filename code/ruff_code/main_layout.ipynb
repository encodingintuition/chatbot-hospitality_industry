# %%
key_towel = '.*\\bi-need-some-towel\\b.*' #"I need some towels"

# %%
#### 
human_input

# %%
# Number of Towels

def numberofTowels(type_of_towel):
    number_of_towels = 0 

    vaReply = "how many ",towel_type, " towels would you like?"
    text_to_speech(vaReply)
    while (True):
    
        # input 
        human_input = speech_to_text()
        # only the numbers
        clean_input = e.sub('\D', '', human_input) 
    
        if clean_input <= 20:
            return clean_input

        elif clean_input > 20:
            vaReply = 'i am sorry the max towels we can send you is 20.  We will send you 20.'    
            text_to_speech(vaReply)
            return 20
        else 
            vaReply = 'I am sorry i did not get that.'
            text_to_speech(vaReply)

# %%
# What is your room number

def roomNumber():

    vaReply = "what is your room number?"
    
    while (True):
    
        # input 
        
        clean_input = re.sub('\D', '', human_input) 
    
    
        if clean_input > 0 & clean_input <=5000:
            vaReply = "thank you "
            vaReply = "we will send it up to room " + clean_input
            return clean_input
        
        else 
            vaReply = 'I am sorry i did not get that.'
            vaReply = "what is your room number?"

# %%
# I need some towels 

def need_towels():
    
    towel_req = [[0,0],
                 [0,0],
                 [0,0],
                 [0,0]]
    
    # Loop for towels

    while(flag == True):
        
        if towel_req[1,0] == 0 & towel_req[2,0] == 0 & towel_req[3,0] == 0: 
            
            exit = False
            vaReply = "what type of towels would you like: bath towel, hand towel, or washcloths"
            
            while exit == False:
            
                # input 
                
                if re.search(--bath --,human_input):
                    towel_req[1,0] = 1 
                    flag = 1
                    
                    # number of towels
                    towel_req[1,1] = #function('bath') 
                    
                    
                if re.search(--hand --,human_input):
                    towel_req[2,0] = 1
                    
                if re.search(--bath --,human_input):
                    towel_req[3,0] = 1
                    
                else 
                    vaReply = " "
                    vaReply = "what type of towels would you like: bath towel, hand towel, or washcloths"

                
                if towel_req != 0 | towel_req != 0 | towel_req != 0:
                    vaReply = "would you liek another type of towel also"
                    
                    #input 
                    
                    if human_input != re.seach(     ):
                        return towel_req
                    else

                
                    
        if towel_att[1] == 0:
            
            while towel_att[1] == 0
        
        # input

# %%
# 

while( flag == True ):
    
    # input human_command
    
    
    # if human_command == bye 
    
    
    # if human command = towels 
    # res ex to find '' command within text. 
    
    if human_input != '':
        
        
        if re.search(key_towel,human_input):
            #true 
        
        else 
            #false
